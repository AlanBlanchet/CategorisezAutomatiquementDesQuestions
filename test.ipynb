# %%
import os

os.environ["CUDA_HOME"] = "/usr/lib/cuda"
# os.environ["NUMBAPRO_NVVM"] = "~/.miniconda3/lib"
# os.environ["NUMBAPRO_LIBDEVICE"] = "~/.miniconda3/lib"
from cuml.cluster import KMeans
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 6
#       3 os.environ["CUDA_HOME"] = "/usr/lib/cuda"
#       4 # os.environ["NUMBAPRO_NVVM"] = "~/.miniconda3/lib"
#       5 # os.environ["NUMBAPRO_LIBDEVICE"] = "~/.miniconda3/lib"
# ----> 6 from cuml.cluster import KMeans
#
# File ~/.cache/pypoetry/virtualenvs/oc--YnkylYD-py3.10/lib/python3.10/site-packages/cuml/__init__.py:17
#       1 #
#       2 # Copyright (c) 2022-2023, NVIDIA CORPORATION.
#       3 #
#    (...)
#      14 # limitations under the License.
#      15 #
# ---> 17 from cuml.internals.base import Base, UniversalBase
#      19 # GPU only packages
#      21 import cuml.common.cuda as cuda
#
# File ~/.cache/pypoetry/virtualenvs/oc--YnkylYD-py3.10/lib/python3.10/site-packages/cuml/internals/__init__.py:17
#       1 #
#       2 # Copyright (c) 2019-2023, NVIDIA CORPORATION.
#       3 #
#    (...)
# ...
